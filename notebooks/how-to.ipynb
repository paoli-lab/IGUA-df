# %% [markdown]
# # Very brief introduction to IGUA-df v.1.0-alpha.4
#
# > NOTE: This version of IGUA is an alpha release. It is intended for testing and feedback purposes only.

# %% [markdown]
# ## Installation
#
# > Note: these are temporary instructions. Once ready, IGUA can be installed as easily as `pip install igua` or `conda install bioconda::igua`.
#
# 1. Install [rust](https://doc.rust-lang.org/stable/book/ch01-01-installation.html?highlight=MacOS).
#     1. ```curl --proto '=https' --tlsv1.2 https://sh.rustup.rs -sSf | sh```
#     2. select option 1
#     3. restart your terminal or run `. "$HOME/.cargo/env"` to update your PATH
#
# 2. Create a dedicated conda environment:
#
#     ```bash
#     conda create igua-df python
#     conda activate igua-df
#     ```
#
# 3. Install MMSeqs2: `conda install bioconda::mmseqs2 maturin python=3.13 pip polars`
#
# 4. For now, install IGUA in editable mode by following the instructions in [this commit](https://github.com/zellerlab/IGUA/commit/6ce03937bb7293ce3490771c523726db049fd0b3). To be more precise:
#     1. clone the repo and `cd` into it:
#     ```bash
#     git clone git@github.com:paoli-lab/IGUA-df.git
#     cd IGUA-df
#     ```
#     2. install in editable mode:
#     ```bash
#     python -m pip install --no-build-isolation -e .
#     ```
#
# 5. Finally, there may be additional missing dependency messages. Please follow them.

# %% [markdown]
# ## Running IGUA-df on a single genome
#
# IGUA-df can be run on a single genome/strain by providing all the required files one by one.
#
# ```bash
# igua \
#   --defense-systems-tsv /path/to/my_strain_defense_finder_systems.tsv \
#   --defense-genes-tsv /path/to/my_strain_defense_finder_genes.tsv \
#   --gff /path/to/my_strain.gff \
#   --genome /path/to/my_strain.fa \
#   --protein-file /path/to/my_strain.faa
# ```
#
# Running this command should result in a successful run of IGUA-df. The logger will indicate that final GCFs table was saved to `gcfs.tsv` in the same directory.

# %% [markdown]
# ## Running IGUA-df on multiple genomes
#
# The other way to run IGUA-df is by providing a single tsv file which contains the paths to the files specified above. IGUA-df is run row by row _i.e._ genome by genome.
#
# ```bash
# igua -i ./strains_metadata.tsv
# ```
#
# To obtain the tsv file, one must run a pre-processing step that identifies all the file paths which will be fed to IGUA-df (raw and annotated data along with the DefenseFinder outputs). Below is a quick function to help with the file detection; feel free to adapt it to your own needs. Please, note that the directory structure this function can work with is limited, as indicated in the docstring.

# %%
import pandas as pd
from pathlib import Path
from typing import Optional

def create_input_metadata_tsv(
    data_dir: str, 
    output_file: str,
) -> str:
    """Create metadata TSV from defense gene cluster data directories.
    
    Args:
        data_dir (str): Path to directory containing defense gene cluster subdirectories.
        output_file (str): Path to output metadata TSV file.
    
    Returns:
        str: Path to the output metadata TSV file.
    """
    data_path = Path(data_dir)
    metadata_rows = []
    
    subdirs = [d for d in data_path.iterdir() if d.is_dir()]
    
    for subdir in subdirs:
        genome_id = subdir.name 
        
        def _find_file(*patterns: str) -> Optional[str]:
            """Search for first file matching any of the given patterns."""
            for pattern in patterns:
                matches = list(subdir.rglob(pattern))
                if matches:
                    return str(matches[0].resolve())
            return None
        
        defense_finder_entry = {
            'genome_id': genome_id, 
            'systems_tsv': _find_file('*defense_finder_systems.tsv'),
            'genes_tsv': _find_file('*defense_finder_genes.tsv'),
            'gff_file': _find_file('*.gff3', '*.gff'),
            'genome_fasta_file': _find_file('*.fasta', '*.fa', '*.fna'), 
            'protein_fasta_file': _find_file('*.faa'), 
        }
        
        metadata_rows.append(defense_finder_entry)
    
    df = pd.DataFrame(metadata_rows)
    df = df[['genome_id', 'systems_tsv', 'genes_tsv', 'gff_file', 'genome_fasta_file', 'protein_fasta_file']]
    df.dropna(inplace=True)
    df.to_csv(output_file, sep='\t', index=False)

    return output_file

# %% [markdown]
# Upon running the function, a `strains_metadata.tsv` will be written. It will contain the paths to the `.fa`, `.gff`, `.faa`, `.fna`, `defense_finder_systems.tsv`, and `defense_finder_genes.tsv` along with some metadata about the strain ID (taken from the folder structure). Some of these files will be fed to IGUA internally.
#
# Note that it is essential for the `metadata.tsv` file to have the following column names: `[genome_id, systems_tsv, genes_tsv, gff_file, genome_fasta_file, protein_fasta_file]` where `fna_file` is optional.

# %%
import os

data_dir = "/path/to/your/data/directory"           # Change to your data directory
test_run_directory = "/path/to/result/directory"    # Change to your desired working directory

create_input_metadata_tsv(
    data_dir=data_dir,  
    output_file=os.path.join(test_run_directory, "strains_metadata.tsv")
)

# %% [markdown]
# Next, from your console, navigate to the test run directory which should contain `strains_metadata.tsv`
#
# ```bash
# cd "/path/to/working/directory"
# ```
#
# We are ready to run IGUA-df:
#
# ```bash
# igua -i ../data/strains_metadata.tsv --dataset-type defense-finder --output gcfs.tsv --compositions compositions.h5ad --features features.fa
# ```
#
# > Note: this command format may change. Currently, dataset-type must be specified as `defense-finder` when using DefenseFinder outputs. The rest of the flags (`--compositions` and `--features`) are standard IGUA flags.
#
# Quickly examine the results, for example as in below.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# quick look at the cluster sizes 
tsv_path = 'path/to/gcfs.tsv' 
gcfs_df = pd.read_csv(tsv_path, sep="\t")
gcfs_df['cluster_length'].hist(bins=100)
plt.xlabel('Cluster Length [bp]')
plt.ylabel('Frequency')
plt.show();
# plt.savefig('hist_cluster_length.pdf')

# %%
# quick look at column summaries 

for col in gcfs_df.columns:
    print(f"Column: {col}")
    print(gcfs_df[col].describe())
    print("\n")

# %% [markdown]
# ## Fileting by activity
#
# To filter the defense systems by activity, use the `--activity` argument. It accepts one of `defense` (default), `antidefense`, or `all` (no filtering).
#
# ```bash
# igua -i ../strains_metadata.tsv --dataset-type defense-finder --activity antidefense
# ```

# %% [markdown]
# ## Verbose defense system extraction feedback
#
# When extracting/writing defense systems, get extra verbose feedback on the number of systems written from every strain and the number of proteins/nucleotide sequences extracted from every system using the `--defense-finder-verbose` option.
#
# ```bash
# igua -i ../strains_metadata.tsv --output gcfs.tsv --dataset-type defense-finder --defense-finder-verbose
# ```
